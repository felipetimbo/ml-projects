# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
childbirth_df = pd.read_csv('datasets/childbirth.csv', sep=';')

# %%
childbirth_df
# Out:
#        ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  ESCMAE  \
# 0           1  7047428.0      230440        1        24        1.0     4.0
# 1           1  2497654.0      230440        1        21        1.0     3.0
# 2           1  2481286.0      230440        1        31        2.0     3.0
# 3           1  2497654.0      230440        1        28        2.0     3.0
# 4           1  2481286.0      230440        1        18        5.0     3.0
# ...       ...        ...         ...      ...       ...        ...     ...
# 40939       1  2651351.0      230440        1        43        2.0     4.0
# 40940       1  2497654.0      230440        1        38        1.0     3.0
# 40941       1  2651351.0      230440        1        25        5.0     3.0
# 40942       1  2497654.0      230440        1        18        2.0     3.0
# 40943       1  2497654.0      230440        1        25        2.0     3.0
#
#        CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  TPFUNCRESP  TPDOCRESP  \
# 0        999992.0         4.0         0.0  ...         2.0          3
# 1        513205.0         3.0         0.0  ...         2.0          3
# 2        999992.0         2.0         0.0  ...         5.0          0
# 3        763015.0         2.0         0.0  ...         2.0          3
# 4        999992.0         2.0         0.0  ...         5.0          0
# ...           ...         ...         ...  ...         ...        ...
# 40939    763010.0         2.0         1.0  ...         5.0          0
# 40940    631010.0         3.0         0.0  ...         2.0          3
# 40941    354705.0         2.0         NaN  ...         5.0          0
# 40942    999992.0         1.0         0.0  ...         2.0          3
# 40943    999992.0         3.0         4.0  ...         2.0          3
#
#        DTDECLARAC  ESCMAEAGR1  STDNEPIDEM  STDNNOVA  CODPAISRES  TPROBSON  \
# 0      11012020.0         5.0           0         1           1         5
# 1      13012020.0         2.0           0         1           1         5
# 2      14012020.0         3.0           0         1           1         5
# 3      13012020.0        11.0           0         1           1         4
# 4      14012020.0         3.0           0         1           1         3
# ...           ...         ...         ...       ...         ...       ...
# 40939  30122020.0         4.0           0         1           1         4
# 40940  17012022.0        11.0           0         1           1         4
# 40941  18012022.0         3.0           0         1           1         3
# 40942  31012022.0        11.0           0         1           1         5
# 40943   1022022.0        11.0           0         1           1        11
#
#        PARIDADE  KOTELCHUCK
# 0             1           2
# 1             1           3
# 2             1           5
# 3             1           5
# 4             1           2
# ...         ...         ...
# 40939         1           5
# 40940         1           2
# 40941         1           5
# 40942         1           2
# 40943         1           9
#
# [40944 rows x 60 columns]

# %%
childbirth_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40944 entries, 0 to 40943
# Data columns (total 60 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ORIGEM      40944 non-null  int64
#  1   CODESTAB    40798 non-null  float64
#  2   CODMUNNASC  40944 non-null  int64
#  3   LOCNASC     40944 non-null  int64
#  4   IDADEMAE    40944 non-null  int64
#  5   ESTCIVMAE   40198 non-null  float64
#  6   ESCMAE      40630 non-null  float64
#  7   CODOCUPMAE  38210 non-null  float64
#  8   QTDFILVIVO  31964 non-null  float64
#  9   QTDFILMORT  26881 non-null  float64
#  10  CODMUNRES   40944 non-null  int64
#  11  GESTACAO    39601 non-null  float64
#  12  GRAVIDEZ    40837 non-null  float64
#  13  PARTO       40887 non-null  float64
#  14  CONSULTAS   40944 non-null  int64
#  15  DTNASC      40944 non-null  int64
#  16  HORANASC    40928 non-null  float64
#  17  SEXO        40944 non-null  int64
#  18  APGAR1      40752 non-null  float64
#  19  APGAR5      40759 non-null  float64
#  20  RACACOR     24209 non-null  float64
#  21  PESO        40943 non-null  float64
#  22  IDANOMAL    38814 non-null  float64
#  23  DTCADASTRO  40944 non-null  int64
#  24  CODANOMAL   762 non-null    object
#  25  NUMEROLOTE  40944 non-null  int64
#  26  VERSAOSIST  40944 non-null  object
#  27  DTRECEBIM   40944 non-null  int64
#  28  DIFDATA     40944 non-null  int64
#  29  DTRECORIGA  0 non-null      float64
#  30  NATURALMAE  40805 non-null  float64
#  31  CODMUNNATU  40805 non-null  float64
#  32  CODUFNATU   40805 non-null  float64
#  33  ESCMAE2010  40630 non-null  float64
#  34  SERIESCMAE  14538 non-null  float64
#  35  DTNASCMAE   40911 non-null  float64
#  36  RACACORMAE  24209 non-null  float64
#  37  QTDGESTANT  33251 non-null  float64
#  38  QTDPARTNOR  27957 non-null  float64
#  39  QTDPARTCES  28391 non-null  float64
#  40  IDADEPAI    2032 non-null   float64
#  41  DTULTMENST  15622 non-null  float64
#  42  SEMAGESTAC  39601 non-null  float64
#  43  TPMETESTIM  39601 non-null  float64
#  44  CONSPRENAT  39474 non-null  float64
#  45  MESPRENAT   37934 non-null  float64
#  46  TPAPRESENT  38638 non-null  float64
#  47  STTRABPART  38233 non-null  float64
#  48  STCESPARTO  36688 non-null  float64
#  49  TPNASCASSI  40841 non-null  float64
#  50  TPFUNCRESP  40857 non-null  float64
#  51  TPDOCRESP   40944 non-null  int64
#  52  DTDECLARAC  40908 non-null  float64
#  53  ESCMAEAGR1  40630 non-null  float64
#  54  STDNEPIDEM  40944 non-null  int64
#  55  STDNNOVA    40944 non-null  int64
#  56  CODPAISRES  40944 non-null  int64
#  57  TPROBSON    40944 non-null  int64
#  58  PARIDADE    40944 non-null  int64
#  59  KOTELCHUCK  40944 non-null  int64
# dtypes: float64(39), int64(19), object(2)
# memory usage: 18.7+ MB

# %%
childbirth_df.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK'],
#       dtype='object')

# %%
sns.heatmap(childbirth_df.isnull(), cbar = False)
# Out:
# <AxesSubplot:>
